# %% [markdown]
# <a href="https://colab.research.google.com/github/rontalapoojareddy/DeepLearning1/blob/main/app_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit pyngrok opencv-python-headless numpy

# %%
# %%writefile app.py

import streamlit as st
import cv2
import numpy as np
import tempfile

st.set_page_config(page_title="Image & Video Processing", layout="wide")

st.title("📷 Image & 🎥 Video Processing App")

option = st.sidebar.selectbox(
    "Choose Input Type",
    ("Image", "Video")
)

# ================= IMAGE =================
if option == "Image":

    st.header("Upload an Image")

    uploaded_image = st.file_uploader(
        "Choose an image...",
        type=["jpg", "jpeg", "png"]
    )

    if uploaded_image is not None:

        file_bytes = np.asarray(
            bytearray(uploaded_image.read()),
            dtype=np.uint8
        )

        img = cv2.imdecode(file_bytes, 1)

        st.subheader("Original Image")
        st.image(img, channels="BGR")

        # Grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        st.subheader("Grayscale Image")
        st.image(gray)

        # Edge Detection
        edges = cv2.Canny(img, 100, 200)
        st.subheader("Edge Detection")
        st.image(edges)

# ================= VIDEO =================
elif option == "Video":

    st.header("Upload a Video")

    uploaded_video = st.file_uploader(
        "Choose a video...",
        type=["mp4", "mov", "avi"]
    )

    if uploaded_video is not None:

        tfile = tempfile.NamedTemporaryFile(delete=False)
        tfile.write(uploaded_video.read())

        cap = cv2.VideoCapture(tfile.name)

        stframe = st.empty()

        while cap.isOpened():
            ret, frame = cap.read()

            if not ret:
                break

            # Convert to grayscale
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

            # Convert back to 3 channel for Streamlit
            gray_3ch = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)

            stframe.image(gray_3ch, channels="BGR")

        cap.release()
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

ngrok.set_auth_token("39iIdnbTZ6XHI5XzSqeV30YHZV7_3etgkV6qZKBSa5SJ57vTj")

# %%
# !streamlit run app.py &>/content/logs.txt &

public_url = ngrok.connect(8501)
public_url
# Out:
# <NgrokTunnel: "https://efflorescent-overemphatical-willow.ngrok-free.dev" -> "http://localhost:8501">
